# %% [markdown]
# ## Module2 Project - e_commerce Brazilian Olist Dataset
#
# ### 1. Ingest
#
# #### Ingest the data into your database/data warehouse ○ E.g., Write Python scripts to load the CSV files into the Google BigQuery
#
# Prepare work environment - Read requirement.txt
#
# Load all csv files into bigquery using python script loadfiles.py

# %% [markdown]
# ### 2. Data Warehouse Design
#
# ● Design a star schema for the e-commerce data
#  ● Create dimension tables (e.g., DimCustomer, DimProduct, DimDate) and fact tables (e.g., FactSales)
#   ● Implement the schema in your chosen database
