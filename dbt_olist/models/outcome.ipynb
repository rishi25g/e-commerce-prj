# %%
import pandas as pd
from pandas_gbq import read_gbq

query = """
SELECT
    sales_id,
    order_id,
    customer_id,
    product_id,
    seller_id,
    order_purchase_timestamp,
    price,
    freight_value,
    total_sale_amount
FROM `your-project.your_dataset.fact_sales``
LIMIT 5
"""

df = read_gbq(query, project_id="      ")

df

# %%
import pandas as pd
from pandas_gbq import read_gbq

query = """
SELECT
    order_id,
    customer_id,
    product_id,
    total_sale_amount,
    order_purchase_timestamp
FROM `your-project.your_dataset.fact_sales`
LIMIT 10;
"""

df = read_gbq(query, project_id="      ")

df
